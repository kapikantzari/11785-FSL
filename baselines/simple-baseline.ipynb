# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp /content/drive/MyDrive/11785/miniImageNet.zip miniImageNet.zip
# !unzip -q miniImageNet.zip
# !rm miniImageNet.zip

# %%
# !cp /content/drive/MyDrive/11785/project/embarrassingly-simple-baseline.zip embarrassingly-simple-baseline.zip
# !unzip -q /content/embarrassingly-simple-baseline.zip

# %%
# !python pretrain_model.py --weights_folder /content/drive/MyDrive/11785/project
# Out:
# tcmalloc: large alloc 2166571008 bytes == 0x561213d3e000 @  0x7f2f576f51e7 0x561170dbdf98 0x561170d88e27 0x561170d8ae20 0x561170f0861a 0x561170f0842e 0x561170ea1802 0x561170d8c6f2 0x561170e43f22 0x561170ed3be3 0x561170e43d38 0x561170d2eae0 0x561170d8c46c 0x561170d8c240 0x561170e00627 0x561170d8dafa 0x561170dfbc0d 0x561170dfa9ee 0x561170d8e48c 0x561170dcf159 0x561170dcc0a4 0x561170d8cd49 0x561170e0094f 0x561170dfa9ee 0x561170dfa6f3 0x561170df8a5b 0x561170ea1802 0x561170d8e7da 0x561170e0118e 0x561170dfa9ee 0x561170d8dbda
# ...

# %%
# !ls
# Out:
# embarrassingly-simple-baseline.zip  resnet12.py
# meta_test_loader.py		    resnet_vanilla.txt
# pretrain_loader.py		    test_pretrain_model.py
# pretrain_model.py		    test_pretrain_model_with_prune.py
# __pycache__			    utils.py
# README.md

# %%
# %cd /content
# %run test_pretrain_model.py
# Out:
# /content
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Finished loading Resnet 12 NN
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# One Shot Test Acc  Mean 0.6041

# %%
# %cd /content
# %run test_pretrain_model_with_prune.py
# Out:
# /content
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Finished loading Resnet 12 NN
# One Shot Test Acc  Mean 0.5403
# LR
# LR One Shot Val Acc 0.5655
# LR
# ...

# %%
import torch
torch.cuda.is_available()
# Out:
# True

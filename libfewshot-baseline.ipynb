# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cp /content/gdrive/MyDrive/miniImageNet--ravi.tar.gz /content/

# %%
# !tar -xf miniImageNet--ravi.tar.gz

# %%
# %cd /content/
# !git clone https://github.com/RL-VIG/LibFewShot.git
# %cd /content/LibFewShot
# Out:
# /content
# Cloning into 'LibFewShot'...
# remote: Enumerating objects: 711, done.
# remote: Counting objects: 100% (711/711), done.
# remote: Compressing objects: 100% (424/424), done.
# remote: Total 711 (delta 442), reused 513 (delta 279), pack-reused 0
# Receiving objects: 100% (711/711), 3.08 MiB | 15.33 MiB/s, done.
# Resolving deltas: 100% (442/442), done.
# /content/LibFewShot

# %%
# %pip install -r requirements.txt

# %%
# TODO: change .yaml to baseline
# TODO: change baseline.yaml to use res12
# TODO: add tensorboardX to requirement.txt
# TODO: make sure data_root is valid
# TODO: change result path
# !python3 run_trainer.py > train.log
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# ...

# %%
# !python3 run_test.py
# Out:
# the model will be performed on CPU.
# [11/03/21 02:08:19] Level 1  Registering FakeQuantWithMinMaxArgs  ]8;id=403958;file:///usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/registry.py\registry.py]8;;\:66
#                              (<function
#                              _FakeQuantWithMinMaxArgsGradient at
#                              0x7f20f6ece3b0>) in gradient.
#                     Level 1  Registering FakeQuantWithMinMaxVars  ]8;id=794772;file:///usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/registry.py\registry.py]8;;\:66
#                              (<function
#                              _FakeQuantWithMinMaxVarsGradient at
#                              0x7f20f6d837a0>) in gradient.
#                     Level 1  Registering                          ]8;id=933488;file:///usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/registry.py\registry.py]8;;\:66
# ...
